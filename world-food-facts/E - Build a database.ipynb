# %% [markdown]
# # E. Build a database

# %% [markdown]
# You will build a database to hold your data. It is up to you to define appropriate tables and well as primary keys for connecting them. (The focus is definitely more on just using the basic methods/tools introduced in the course and not on building a complex database.) In particular, you can follow the following list of steps:
#
# * restrict your data to 1000 entries and 5 columns of your choice
# * create a connection to a sqlite3 database
# * create one or multiple tables, at least one of the tables should have a PRIMARY KEY
# * fill the database with your data
# * run at least one query to demonstrate that it works correctly

# %%
# import the data that seems to be tab seperated
import pandas as pd
import numpy as np
import seaborn as sns
import sqlite3

# %%
pd.set_option('display.max_columns', 200)

# %%
# We will work on a subset of the columns
columns_product = [
    'code', 'product_name', 'countries_en', 'serving_size', 'energy_100g', 'nutrition_score_uk_100g'
]

columns_nutrient = ['code', 'product_name', 'proteins_100g', 'fat_100g', 'cholesterol_100g','carbohydrates_100g','sugars_100g' ]

# Load the DataFrame, we will work on the first 1000 rows and limit to 5 columns
#df=pd.read_csv("C:/Users/tgdkujo2/Documents/EPFL_Data_Analytics/2 - APPLIED DATA ANALYSIS/09. Course Project/world-food-facts/en.openfoodfacts.org.products.tsv",  nrows=1000, usecols=columns, sep="\t", low_memory=False)
df=pd.read_csv("C:/Users/tgdkujo2/Documents/EPFL_Data_Analytics/2 - APPLIED DATA ANALYSIS/09. Course Project/world-food-facts/en.openfoodfacts.org.products.tsv",  sep="\t", low_memory=False)

#df.set_index('code', inplace=True)
# rename columns that contain a "-", because they cause a problem in the database
df = df.rename(columns={'nutrition-score-uk_100g': 'nutrition_score_uk_100g'})

# %% [markdown]
# **Create an empty Database**

# %%
db = sqlite3.connect("my_database.db")

# %% [markdown]
# **Create Tables**

# %%
query_product= "CREATE TABLE products (code INTEGER PRIMARY KEY, product_name TEXT, countries_en TEXT, serving_size float, energy_100g float, nutrition_score_uk_100g int);"
query_nutrient= "CREATE TABLE nutrient (code INTEGER PRIMARY KEY, product_name TEXT, proteins_100g TEXT, fat_100g float, cholesterol_100g float, carbohydrates_100g float, sugars_100g float);"

# %%
# open a Cursor
cursor = db.cursor()

# %%
#cursor.execute("DROP TABLE products;")
#cursor.execute("DROP TABLE nutrient;")
db.commit()

# %%
cursor.execute(query_product)
cursor.execute(query_nutrient)
db.commit()

# %%
# check the tables
cursor.execute("SELECT name FROM sqlite_master where type='table';")
results = cursor.fetchall()
print(results)
# Out:
# [('products',), ('nutrient',)]

# %% [markdown]
# **Loading Data from DataFram to Database**

# %%
df_sample = df.sample(n=1000)
df_sample[columns_product].to_sql(name='products', con=db, if_exists='replace', index=False)
df_sample[columns_nutrient].to_sql(name='nutrient', con=db, if_exists='replace', index=False)

# %% [markdown]
# **Running a Test Query**

# %%
def run_query(query):
    return pd.read_sql_query(query, db)

# %%
run_query("SELECT * from products limit 10;")
# Out:
#             code                                       product_name  \
# 0       26122762                                        Creamy Aoli
# 1       20186258                                   Stir fry noodles
# 2  8712566221059                          Soupe Tomate Céleri Ligne
# 3  3392460482012  Forme+ (5 Vitamines & 4 Minéraux), Céréale Com...
# 4  3266980931551                                               None
# 5  0078742133225                     Grate Value, Almonds, Sea Salt
# 6       20492915                              Manzanas Granny Smith
# 7  0073711415548      Rye Bread With Caraway Seeds, Restaurant Size
# 8  5060424400362                                               None
# 9  0087688067761                         Spiced Bacon Ends & Pieces
#
#      countries_en         serving_size  energy_100g  nutrition_score_uk_100g
# 0       Australia                 None          NaN                      NaN
# 1         Belgium                 None          NaN                      NaN
# 2          France                 None         84.0                      1.0
# 3          France  1 biscotte (8,20 g)       1625.0                      7.0
# 4          France                 None          NaN                      NaN
# 5   United States         28 g (1 ONZ)       2540.0                      8.0
# 6           Spain                 None          NaN                      NaN
# 7   United States          38 g (38 g)       1100.0                      9.0
# 8  United Kingdom                 None          NaN                      NaN
# 9   United States       14 g (0.5 ONZ)       2092.0                     26.0

# %%
run_query("SELECT count(*) from products;")
# Out:
#    count(*)
# 0      1000

# %%
run_query("SELECT * from nutrient limit 10;")
# Out:
#             code                                       product_name  \
# 0       26122762                                        Creamy Aoli
# 1       20186258                                   Stir fry noodles
# 2  8712566221059                          Soupe Tomate Céleri Ligne
# 3  3392460482012  Forme+ (5 Vitamines & 4 Minéraux), Céréale Com...
# 4  3266980931551                                               None
# 5  0078742133225                     Grate Value, Almonds, Sea Salt
# 6       20492915                              Manzanas Granny Smith
# 7  0073711415548      Rye Bread With Caraway Seeds, Restaurant Size
# 8  5060424400362                                               None
# 9  0087688067761                         Spiced Bacon Ends & Pieces
#
#    proteins_100g  fat_100g  cholesterol_100g  carbohydrates_100g  sugars_100g
# 0            NaN       NaN               NaN                 NaN          NaN
# 1            NaN       NaN               NaN                 NaN          NaN
# 2           0.70       NaN               NaN                 NaN         1.00
# 3          15.00      6.00               NaN               63.00         7.70
# 4            NaN       NaN               NaN                 NaN          NaN
# 5          21.43     53.57             0.000               17.86         3.57
# 6            NaN       NaN               NaN                 NaN          NaN
# 7           7.89      3.95             0.000               47.37         0.00
# 8            NaN       NaN               NaN                 NaN          NaN
# 9          42.86     32.14             0.107                0.00         0.00

# %%
run_query("SELECT count(*) from nutrient;")
# Out:
#    count(*)
# 0      1000

# %%
run_query('''select p.product_name, p.nutrition_score_uk_100g, n.proteins_100g, n.fat_100g, n.cholesterol_100g, n.carbohydrates_100g
          from products p inner join nutrient n on p.code=n.code where p.nutrition_score_uk_100g > 0''')
# Out:
#                                           product_name  \
# 0                            Soupe Tomate Céleri Ligne
# 1    Forme+ (5 Vitamines & 4 Minéraux), Céréale Com...
# 2                       Grate Value, Almonds, Sea Salt
# 3        Rye Bread With Caraway Seeds, Restaurant Size
# 4                           Spiced Bacon Ends & Pieces
# 5                                  Smoked Pork Sausage
# 6                               Mediterranean Apricots
# 7                      Potatoes With Cheese Sauce Mix.
# 8                             Gluten Free Mac & Cheese
# 9                                Pain Gris Pur Froment
# 10           Chocolat au lait du pays Alpin (lot de 4)
# 11                             Nectar gourmand abricot
# 12                     Toaster Pastries, Frosted Fudge
# 13              Sugar In The Raw, Turbinado Cane Sugar
# 14                         Cure 81, Classic Dinner Ham
# 15                  Ciabatta rustica schar sans gluten
# 16                 British Shortcrust Pastry Steak Pie
# 17       Dés de fromage de brebis - herbes de Provence
# 18                               Frosted Sugar Cookies
# 19                          Chewing gum parfum menthol
# 20                    Bâtonnets Tendres (28 Bâtonnets)
# 21                      8 tortillas wraps multi-grains
# 22                                          Vegecheese
# 23                                Dutch Chocolate Milk
# 24                          Fad Free Tuna Spicy Chilli
# 25   Organics, Organic Cooked Pudding & Pie Filling...
# 26                                   Allumettes Nature
# 27                                      Potato Gnocchi
# 28                             Whole Earth Corn Flakes
# 29                                       Valflora Soft
# ..                                                 ...
# 525                               Olympos, Greek Beets
# 526                                Walnut Light Pieces
# 527              Brand, Young Coconut Juice With Jelly
# 528                             Dressing And Marinades
# 529                                     Diced Tomatoes
# 530       Les Dragées Les Classiques au coeur d'Amande
# 531                   Pain de mie Nature (24 Tranches)
# 532  The Brigittine Monks, Gourmet Chocolate Fudge ...
# 533                                             Hotdog
# 534                Greek Yogurt, Mint & Dark Chocolate
# 535                      Sliced Peaches In Heavy Syrup
# 536     Core, Meal, Hearty Oatmeal To Go, Cashew Cacao
# 537                                      Perle De Lait
# 538                          San Pellegrino Aranciata
# 539                                  White Sticky Rice
# 540                                 Club Jambon Beurre
# 541                             P$$T..., Sugar Cookies
# 542                                           Lait bio
# 543                                            Kringle
# 544                                  Graisse de canard
# 545                                    Doritos Tex-Mex
# 546                             Vietnamese Spring Roll
# 547                                       Pudding Cups
# 548                          Façon Charcutière Merguez
# 549                              Klädes Holmen Herring
# 550                                      Chick-O-Stick
# 551                                               None
# 552                                        German Cake
# 553              Ubr, Soft Round Granola Bar, Cinnamon
# 554            Boudins blancs de volaille aux morilles
#
#      nutrition_score_uk_100g  proteins_100g  fat_100g  cholesterol_100g  \
# 0                        1.0           0.70       NaN               NaN
# 1                        7.0          15.00      6.00               NaN
# 2                        8.0          21.43     53.57             0.000
# 3                        9.0           7.89      3.95             0.000
# 4                       26.0          42.86     32.14             0.107
# 5                       20.0          13.79     24.14             0.043
# 6                        8.0           2.70      0.00             0.000
# 7                        9.0           7.14      0.00             0.000
# 8                        5.0           7.93     10.13             0.031
# 9                       13.0           8.05       NaN               NaN
# 10                      25.0           6.40     29.50               NaN
# 11                       2.0           0.50      0.50               NaN
# 12                      17.0           5.77      9.62             0.000
# 13                      14.0           0.00      0.00               NaN
# 14                      12.0          16.67      4.17             0.042
# 15                      13.0           5.80      8.20               NaN
# 16                       4.0           9.40     14.60               NaN
# 17                      23.0          13.70     25.50               NaN
# 18                      23.0           2.63     15.79             0.026
# 19                      13.0           0.50      0.00               NaN
# 20                       4.0           7.40      4.30               NaN
# 21                       4.0           8.70      7.00               NaN
# 22                      21.0           0.12     23.00               NaN
# 23                       4.0           3.33      3.33             0.012
# 24                       5.0          15.20      5.20               NaN
# 25                      17.0           0.00      0.00             0.000
# 26                      23.0          16.20     25.00               NaN
# 27                       1.0           3.45      2.07             0.000
# 28                       3.0           8.00      0.80               NaN
# 29                      16.0           0.50     55.00               NaN
# ..                       ...            ...       ...               ...
# 525                      1.0           0.00      0.00             0.000
# 526                      9.0          16.67     66.67             0.000
# 527                      1.0           0.00      0.00             0.000
# 528                      5.0           0.00      0.00             0.000
# 529                      1.0           0.81      0.41             0.000
# 530                     17.0           9.60     20.10               NaN
# 531                      1.0           8.20      3.80               NaN
# 532                     21.0           4.76     19.05             0.024
# 533                     19.0           8.89     20.00             0.067
# 534                      3.0           7.07      6.06             0.020
# 535                      2.0           0.78      0.00             0.000
# 536                     11.0          22.35     24.71             0.024
# 537                      6.0           2.30       NaN               NaN
# 538                      2.0           0.00      0.00               NaN
# 539                      1.0           2.86      0.24             0.000
# 540                     12.0           9.20     11.00               NaN
# 541                     19.0           3.57     17.86             0.000
# 542                      1.0           3.20       NaN               NaN
# 543                     14.0           3.85     13.46             0.010
# 544                     20.0           0.00    100.00               NaN
# 545                     16.0           7.50     26.40               NaN
# 546                      4.0           2.11      0.35             0.000
# 547                      5.0           1.01      2.02             0.000
# 548                     20.0          12.00     25.00               NaN
# 549                     17.0           7.50       NaN               NaN
# 550                     21.0           5.88     14.71             0.000
# 551                      3.0           3.50      5.00               NaN
# 552                     20.0           5.36     12.50             0.062
# 553                     13.0           8.06     12.90             0.008
# 554                     12.0           9.50     17.00               NaN
#
#      carbohydrates_100g
# 0                   NaN
# 1                 63.00
# 2                 17.86
# 3                 47.37
# 4                  0.00
# 5                  1.72
# 6                 62.16
# 7                 78.57
# 8                 26.87
# 9                   NaN
# 10                58.50
# 11                11.70
# 12                71.15
# 13               100.00
# 14                 2.38
# 15                39.60
# 16                23.50
# 17                 0.90
# 18                65.79
# 19                76.00
# 20                12.00
# 21                52.40
# 22                20.00
# 23                11.67
# 24                 9.50
# 25                96.00
# 26                 0.90
# 27                31.72
# 28                80.00
# 29                 1.00
# ..                  ...
# 525                3.57
# 526               10.00
# 527                7.14
# 528               13.33
# 529                5.69
# 530               61.00
# 531               50.60
# 532               64.29
# 533                4.44
# 534               14.14
# 535               17.19
# 536               44.71
# 537                 NaN
# 538               10.00
# 539               35.71
# 540               26.60
# 541               60.71
# 542                 NaN
# 543               44.23
# 544                0.00
# 545               58.90
# 546               80.70
# 547               21.21
# 548                2.90
# 549                 NaN
# 550               70.59
# 551                5.00
# 552               55.36
# 553               70.97
# 554                4.50
#
# [555 rows x 6 columns]

# %% [markdown]
# **Randomly selecting 1000 rows from our DataFrame**
